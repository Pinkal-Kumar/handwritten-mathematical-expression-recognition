# %%
import pandas as pd

# %%
v = pd.read_json("AttDecoder_bad_case.json")

# %%
v
# Out:
#                                                 18_em_14  18_em_16  \
# label  \frac { d y } { d x } = \frac { 1 } { \frac { ...  m \geq 2
# predi        \frac { d y } { d x } = \frac { 1 } { d x }  m \sum 2
#
#                                                18_em_18  \
# label  \theta _ { 3 } = \theta _ { 1 } + \theta _ { 2 }
# predi          \theta _ { 3 } = \theta + \theta _ { 2 }
#
#                                       18_em_21  \
# label  1 0 1 1 1 1 1 0 1 1 1 0 0 1 0 1 _ { 2 }
# predi    1 0 1 1 1 1 1 0 1 4 0 0 1 0 L _ { 2 }
#
#                                                 18_em_22  \
# label  p _ { 1 } ^ { \gamma _ { 1 } } p _ { 2 } ^ { \...
# predi  p _ { 1 } ^ { \gamma _ { 1 } } p _ { 2 } ^ { \...
#
#                                                  18_em_2  \
# label  C _ { 1 } y _ { 1 } ^ { ( n - 1 ) } + C _ { 2 ...
# predi  ( y _ { 1 } ^ { ( n - 1 ) } + ( _ { 2 } y _ { ...
#
#                          18_em_6  \
# label  g ( b ) - g ( a ) = b - a
# ...
